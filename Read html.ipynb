# %%
import pandas as pd

# %%
dflist=pd.read_html('https://en.wikipedia.org/wiki/States_and_union_territories_of_India')

# %%
dflist[0].head()
# Out:
#   States and union territories of India  \
# 0                              Category
# 1                              Location
# 2                                Number
# 3                           Populations
# 4                                 Areas
#
#              States and union territories of India.1
# 0                                   Federated states
# 1                                  Republic of India
# 2                       27 States8 Union territories
# 3  States: Sikkim - 610,577 (lowest); Uttar Prade...
# 4  States: 3,702 km2 (1,429 sq mi) Goa – 342,269 ...

# %%
dflist[3].head()
# Out:
#                State ISO 3166-2:IN Vehiclecode           Zone  \
# 0     Andhra Pradesh         IN-AP          AP       Southern
# 1  Arunachal Pradesh         IN-AR          AR  North-Eastern
# 2              Assam         IN-AS          AS  North-Eastern
# 3              Bihar         IN-BR          BR        Eastern
# 4       Chhattisgarh         IN-CT          CG        Central
#
#                                              Capital   Largest city  \
# 0  Hyderabad (de jure)Amaravati (de facto) Note 1...  Visakhapatnam
# 1                                           Itanagar       Itanagar
# 2                                             Dispur       Guwahati
# 3                                              Patna          Patna
# 4                                        Naya Raipur         Raipur
#
#           Statehood Population[36] Area(km2) Officiallanguages[37]  \
# 0   1 November 1956       49506799    160205                Telugu
# ...

# %%
# All records
dflist[3]
# Out:
#                 State ISO 3166-2:IN Vehiclecode           Zone  \
# 0      Andhra Pradesh         IN-AP          AP       Southern
# 1   Arunachal Pradesh         IN-AR          AR  North-Eastern
# 2               Assam         IN-AS          AS  North-Eastern
# 3               Bihar         IN-BR          BR        Eastern
# 4        Chhattisgarh         IN-CT          CG        Central
# 5                 Goa         IN-GA          GA        Western
# 6             Gujarat         IN-GJ          GJ        Western
# 7             Haryana         IN-HR          HR       Northern
# 8    Himachal Pradesh         IN-HP          HP       Northern
# 9           Jharkhand         IN-JH          JH        Eastern
# 10          Karnataka         IN-KA          KA       Southern
# 11             Kerala         IN-KL          KL       Southern
# 12     Madhya Pradesh         IN-MP          MP        Central
# 13        Maharashtra         IN-MH          MH        Western
# ...
